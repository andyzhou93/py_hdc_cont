# %%
from sklearn.datasets import make_blobs
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns

X,y = make_blobs(n_samples=np.array([200,100,100,200]),
                 n_features=2,
                 centers=None,
                 cluster_std=0.7,
                 center_box=(-10,10),
                 shuffle=False,
                 random_state=None)

f,ax = plt.subplots(figsize=(10,10))
sns.scatterplot(*X.T,hue=y)

# %%
import numpy as np
temp = np.array(y)
# temp[temp==3] = 1
temp[temp==2] = 1
y = list(temp)
f,ax = plt.subplots(figsize=(10,10))
sns.scatterplot(*X.T,hue=y)

# %%
from sklearn_lvq import RslvqModel, GlvqModel, GrlvqModel

rslvq = RslvqModel(prototypes_per_class=2,
                  initial_prototypes=None,
                  sigma=1.5,
                  max_iter=10000,
                  gtol=1e-7,
                  display=False,
                  random_state=None).fit(X,y)

glvq = GlvqModel(prototypes_per_class=2,
                 initial_prototypes=None,
                 max_iter=10000,
                 gtol=1e-7,
                 beta=2,
                 C=None,
                 display=False,
                 random_state=None).fit(X,y)

grlvq = GrlvqModel(prototypes_per_class=2,
                  initial_prototypes=None,
                  initial_relevances=None,
                  max_iter=10000,
                  gtol=1e-7,
                  beta=2,
                  C=None,
                  display=False,
                  random_state=None).fit(X,y)

# %%
f,ax = plt.subplots(figsize=(10,10))
sns.scatterplot(*X.T,hue=y)
sns.scatterplot(*glvq.w_.T,hue=glvq.c_w_, marker='P',s=1000)
plt.show()
accuracy_score(glvq.predict(X),y)

# %%
f,ax = plt.subplots(figsize=(10,10))
sns.scatterplot(*X.T,hue=y)
sns.scatterplot(*rslvq.w_.T,hue=rslvq.c_w_, marker='P',s=1000)
plt.show()
accuracy_score(glvq.predict(X),y)

# %%
f,ax = plt.subplots(figsize=(10,10))
sns.scatterplot(*X.T,hue=y)
sns.scatterplot(*grlvq.w_.T,hue=grlvq.c_w_, marker='P',s=1000)
plt.show()
accuracy_score(grlvq.predict(X),y)
