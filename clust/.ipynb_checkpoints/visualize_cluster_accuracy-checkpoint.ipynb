# %%
import pickle

import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np
import pandas as pd

from scipy.spatial.distance import cdist, pdist
from sklearn.metrics import accuracy_score
sns.set_context('poster')
sns.set_style("whitegrid")

# %%
with open('./run0-8.pickle','rb') as f:
    agglom_res = pickle.load(f)
    
with open('./run9-12.pickle','rb') as f:
    agglom_res.extend(pickle.load(f))

# %%
# f,ax = plt.subplots(3,5,figsize=(36,20))
# ax = ax.flatten()

# for g in range(len(agglom_res)):
#     sns.heatmap(agglom_res[g]['acc'].T,vmin=0,vmax=1,annot=False,ax=ax[g])

# %%
f,ax = plt.subplots(3,5,figsize=(50,30))
ax = ax.flatten()
maxClust = 12
df = pd.DataFrame()
for g in range(len(agglom_res)):
    temp = agglom_res[g]['acc'][:maxClust,:maxClust].flatten()
    numOutClust = np.tile(np.arange(1,maxClust+1),[maxClust,1]).flatten()
    numInClust = np.tile(np.arange(1,maxClust+1),[maxClust,1]).T.flatten()
    res = pd.DataFrame(data={'Accuracy':temp,'Clusters in tested class':numInClust,'Clusters in other classes':numOutClust,'Gesture':g*np.ones(len(numInClust))})
    sns.lineplot(x='Clusters in tested class',y='Accuracy',hue='Clusters in other classes',data=res,ax=ax[g])
    ax[g].set(ylim=(0,1),title='Testing gesture %d' % g)
    ax[g].legend(loc='lower right')
    df = df.append(res,ignore_index=True)
for a in ax[g+1:]:
    a.axis('off')

# %%
# f,ax = plt.subplots(figsize=(20,20))
# sns.lineplot(x='Clusters in tested class',y='Accuracy',hue='Clusters in other classes',err_style=None,data=df,ax=ax)
# sns.lineplot(x='Clusters in tested class',y='Accuracy',err_style=None,data=df.loc[df['Clusters in tested class'] == df['Clusters in other classes']],color='r',ax=ax)

# %%
# select dataset and encoding type
dataName = 'allHV.npz'
emgHVType =  'hvRel'

allHV = np.load(dataName)

# extract data and labels based on gesture, trial, and position
hv = allHV[emgHVType]
gestLabel = allHV['gestLabel']
posLabel = allHV['posLabel']
trialLabel = allHV['trialLabel']

# get list of unique values for each label
gestures = np.unique(gestLabel)
positions = np.unique(posLabel)
trials = np.unique(trialLabel)

numGestures = len(gestures)
numPositions = len(positions)
numTrials = len(trials)

# get data size info
D = hv.shape[1] # hypervector dimension
numHV = 80 # number of examples per trial

# color palettes for plotting
gPalette = sns.color_palette('Paired', numGestures)
pPalette = sns.color_palette('Paired', numPositions)

# %%
allLabels = []
for g in gestures:
    with open('./clusters/labels_' + str(g) + '_test.pickle', 'rb') as f:
        allLabels.append(pickle.load(f))

# %%
optNumClust = [7, 7, 4, 2, 2, 2, 5, 8, 2, 5, 6, 5, 5]

# %%
def bipolarize(Y):
    X = np.copy(Y)
    X[X > 0] = 1.0
    X[X < 0] = -1.0
    X[X == 0] = np.random.choice([-1.0, 1.0], size=len(X[X == 0]))
    return X

# %%
def centroids(X,label=None,doMean=False):
    if label is not None:
        c = np.zeros((len(np.unique(label)), X.shape[1]))
        for i,l in enumerate(np.unique(label)):
            if doMean:
                c[i,:] = np.mean(X[label==l],axis=0)
            else:
                c[i,:] = bipolarize(np.sum(X[label==l],axis=0))
    else:
        if doMean:
            c = np.mean(X,axis=0).reshape(1,-1)
        else:
            c = bipolarize(np.sum(X,axis=0)).reshape(1,-1)
    return c

# %%
bestCent = []
bestLabels = []
for g in gestures:
    X = np.copy(hv[gestLabel == g])
    l = allLabels[g][optNumClust[g]]
    bestCent.append(centroids(X,label=l))
    for i in range(optNumClust[g]):
        bestLabels.append(g)
bestCent = np.vstack(bestCent)
bestLabels = np.array(bestLabels)
d = cdist(hv,bestCent)
pred = bestLabels[np.argmin(d,axis=1)]

# %%
pred = bestLabels[np.argmin(d,axis=1)]

# %%
accuracy_score(pred,gestLabel)
# Out:
# 0.9664663461538462

# %%
np.vstack(bestCent).shape
# Out:
# (60, 10000)

# %%
membership = {}
for g in gestures:
    posFilt = posLabel[gestLabel==g]
    for n in range(1,31):
        clustering = allLabels[g][n]
        membership[(g,n)] = [np.unique(posFilt[clustering == c],return_counts=True) for c in np.unique(clustering)]

# %%
membership[(0,7)]
# Out:
# [(array([2], dtype=int8), array([240])),
#  (array([6, 7], dtype=int8), array([240, 240])),
#  (array([5], dtype=int8), array([240])),
#  (array([0], dtype=int8), array([240])),
#  (array([1], dtype=int8), array([240])),
#  (array([3], dtype=int8), array([240])),
#  (array([4], dtype=int8), array([240]))]

# %%
membership[(1,7)]
# Out:
# [(array([2], dtype=int8), array([240])),
#  (array([6, 7], dtype=int8), array([240, 240])),
#  (array([5], dtype=int8), array([240])),
#  (array([0], dtype=int8), array([240])),
#  (array([3], dtype=int8), array([240])),
#  (array([1], dtype=int8), array([240])),
#  (array([4], dtype=int8), array([240]))]

# %%
membership[(2,4)]
# Out:
# [(array([6, 7], dtype=int8), array([240, 238])),
#  (array([2, 3], dtype=int8), array([240, 240])),
#  (array([1, 4], dtype=int8), array([235, 235])),
#  (array([0, 1, 4, 5, 7], dtype=int8), array([240,   5,   5, 240,   2]))]

# %%
membership[(3,2)]
# Out:
# [(array([2, 6, 7], dtype=int8), array([240, 240, 240])),
#  (array([0, 1, 3, 4, 5], dtype=int8), array([240, 240, 240, 240, 240]))]

# %%
membership[(4,2)]
# Out:
# [(array([2, 6, 7], dtype=int8), array([240, 240, 240])),
#  (array([0, 1, 3, 4, 5], dtype=int8), array([240, 240, 240, 240, 240]))]

# %%
membership[(5,2)]
# Out:
# [(array([2, 6, 7], dtype=int8), array([240, 240, 240])),
#  (array([0, 1, 3, 4, 5], dtype=int8), array([240, 240, 240, 240, 240]))]

# %%
membership[(6,5)]
# Out:
# [(array([2], dtype=int8), array([240])),
#  (array([5, 6, 7], dtype=int8), array([  5, 240, 240])),
#  (array([0, 1, 5], dtype=int8), array([240, 240, 235])),
#  (array([4], dtype=int8), array([240])),
#  (array([3], dtype=int8), array([240]))]

# %%
membership[(7,8)]
# Out:
# [(array([6, 7], dtype=int8), array([221,  14])),
#  (array([2], dtype=int8), array([240])),
#  (array([6, 7], dtype=int8), array([ 18, 226])),
#  (array([0], dtype=int8), array([240])),
#  (array([1, 5, 6], dtype=int8), array([  5, 240,   1])),
#  (array([4], dtype=int8), array([240])),
#  (array([1], dtype=int8), array([235])),
#  (array([3], dtype=int8), array([240]))]

# %%
membership[(8,2)]
# Out:
# [(array([2, 6, 7], dtype=int8), array([240, 240, 240])),
#  (array([0, 1, 3, 4, 5], dtype=int8), array([240, 240, 240, 240, 240]))]

# %%
membership[(9,5)]
# Out:
# [(array([2], dtype=int8), array([240])),
#  (array([6, 7], dtype=int8), array([240, 240])),
#  (array([3, 4], dtype=int8), array([240, 240])),
#  (array([1], dtype=int8), array([240])),
#  (array([0, 5], dtype=int8), array([240, 240]))]

# %%
membership[(10,6)]
# Out:
# [(array([2], dtype=int8), array([240])),
#  (array([6, 7], dtype=int8), array([240, 240])),
#  (array([0], dtype=int8), array([240])),
#  (array([3, 4], dtype=int8), array([240, 240])),
#  (array([5], dtype=int8), array([240])),
#  (array([1], dtype=int8), array([240]))]

# %%
membership[(11,5)]
# Out:
# [(array([2], dtype=int8), array([240])),
#  (array([6, 7], dtype=int8), array([240, 240])),
#  (array([1], dtype=int8), array([240])),
#  (array([3, 4], dtype=int8), array([240, 240])),
#  (array([0, 5], dtype=int8), array([240, 240]))]

# %%
membership[(12,5)]
# Out:
# [(array([2], dtype=int8), array([240])),
#  (array([6, 7], dtype=int8), array([240, 240])),
#  (array([1], dtype=int8), array([240])),
#  (array([3, 4], dtype=int8), array([240, 240])),
#  (array([0, 5], dtype=int8), array([240, 240]))]
