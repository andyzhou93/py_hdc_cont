# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
import h5py
import hdc
import numpy as np
from sklearn import svm
from itertools import combinations
import scipy.io as sio
from sklearn_lvq import GlvqModel
from sklearn.cluster import DBSCAN
from scipy.cluster.hierarchy import dendrogram, linkage
from tqdm import tqdm

dataName = 'allHV.npz'
emgHVType = 'hvRel' # hvRel hvRelAcc hvAbs hvAbsAcc
contextType = 'none' # none random
clusterType = 'single' # single separate auto
autoThreshold = 0 # 0 - 100
numTrainPositions = 1 # 1 - 8
crossTrial = 'within' # cross within
doLVQ = 'lvqOn' # lvqOn lvqOff
numIters = 1

if clusterType == 'auto':
    matName = emgHVType + '_' + contextType + '_' + clusterType + '_' + str(autoThreshold) + '_' + str(numTrainPositions) + '_' + crossTrial + '_' + doLVQ + '_' + str(numIters) + '.mat'
else:
    matName = emgHVType + '_' + contextType + '_' + clusterType + '_' + str(numTrainPositions) + '_' + crossTrial + '_' + doLVQ +  '_' + str(numIters) + '.mat'

autoThreshold = float(autoThreshold/100)


allHV = np.load(dataName)
hv = allHV[emgHVType]
gestLabel = allHV['gestLabel']
posLabel = allHV['posLabel']
trialLabel = allHV['trialLabel']

gestures = np.unique(gestLabel)
positions = np.unique(posLabel)
trials = np.unique(trialLabel)

numGestures = len(gestures)
numPositions = len(positions)
numTrials = len(trials)

D = hv.shape[1]
numHV = 80

if contextType == 'random':
    contextVec = np.random.choice([-1.0, 1.0], size=(numPositions,D))

trainCombinations = list(combinations(np.arange(numPositions),numTrainPositions))
numCombinations = len(trainCombinations)

# output data to be put into struct
meanHDAcc = np.zeros((numCombinations,numPositions))

# %%
allowedOutliers = [0,1,2,4,8,16]
trialEps = np.zeros((len(allowedOutliers),numGestures,numPositions,numTrials))
trialNumClust = np.zeros((len(allowedOutliers),numGestures,numPositions,numTrials))
trialClustSizes = np.zeros((len(allowedOutliers),numGestures,numPositions,numTrials,numHV))
for g in range(numGestures):
    for p in range(numPositions):
        for t in range(numTrials):
            for i,o in enumerate(allowedOutliers):
                # find minimum hamming distance epsilon per trial
                minSamples = 2
                currEps = 0.6
                lowEps = 0
                highEps = 0.6
                deltaEps = highEps - lowEps
                print('G%d-P%d-T%d:' % (g,p,t), end=" ")
                numIter = 12
                for x in range(numIter):
                    db = DBSCAN(eps=currEps,min_samples=minSamples,metric='hamming',n_jobs=-1).fit(hv[(gestLabel==g) & (posLabel==p) & (trialLabel==t)])
                    numOutliers = len(db.labels_[db.labels_<0])
                    if numOutliers <= o:
                        highEps = currEps
                        currEps = np.mean([currEps,lowEps])
                        clusts = np.unique(db.labels_[db.labels_>=0])
                        trialNumClust[i,g,p,t] = len(clusts)
                        bestNumOutliers = len(db.labels_[db.labels_<0])
                        clustSizes = []
                        for c in clusts:
                            clustSizes.append(len(db.labels_[db.labels_==c]))
                        trialClustSizes[i,g,p,t,:] = db.labels_
                        
                    else:
                        lowEps = currEps
                        currEps = np.mean([currEps,highEps])
                    deltaEps = highEps - lowEps
                print('eps = %f, %d clusters with %d outliers, %d standard deviation in cluster size ' % (highEps, trialNumClust[i,g,p,t], bestNumOutliers, round(np.std(clustSizes))))
                trialEps[i,g,p,t] = highEps
# Out:
# G0-P0-T0: eps = 0.211230, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G0-P0-T0: eps = 0.210059, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G0-P0-T0: eps = 0.209473, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G0-P0-T0: eps = 0.209180, 1 clusters with 3 outliers, 0 standard deviation in cluster size
# G0-P0-T0: eps = 0.206250, 1 clusters with 8 outliers, 0 standard deviation in cluster size
# G0-P0-T0: eps = 0.203320, 1 clusters with 16 outliers, 0 standard deviation in cluster size
# G0-P0-T1: eps = 0.219434, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G0-P0-T1: eps = 0.219141, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G0-P0-T1: eps = 0.217676, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G0-P0-T1: eps = 0.217090, 1 clusters with 4 outliers, 0 standard deviation in cluster size
# G0-P0-T1: eps = 0.215918, 1 clusters with 7 outliers, 0 standard deviation in cluster size
# G0-P0-T1: eps = 0.213867, 1 clusters with 15 outliers, 0 standard deviation in cluster size
# G0-P0-T2: eps = 0.287695, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G0-P0-T2: eps = 0.286523, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G0-P0-T2: eps = 0.283008, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G0-P0-T2: eps = 0.273340, 1 clusters with 4 outliers, 0 standard deviation in cluster size
# G0-P0-T2: eps = 0.211816, 1 clusters with 8 outliers, 0 standard deviation in cluster size
# G0-P0-T2: eps = 0.207129, 2 clusters with 16 outliers, 30 standard deviation in cluster size
# G0-P1-T0: eps = 0.277441, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G0-P1-T0: eps = 0.277441, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G0-P1-T0: eps = 0.275684, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G0-P1-T0: eps = 0.268359, 1 clusters with 4 outliers, 0 standard deviation in cluster size
# G0-P1-T0: eps = 0.210059, 2 clusters with 8 outliers, 33 standard deviation in cluster size
# G0-P1-T0: eps = 0.203906, 2 clusters with 15 outliers, 30 standard deviation in cluster size
# G0-P1-T1: eps = 0.200977, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G0-P1-T1: eps = 0.196875, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G0-P1-T1: eps = 0.196875, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G0-P1-T1: eps = 0.196289, 1 clusters with 4 outliers, 0 standard deviation in cluster size
# G0-P1-T1: eps = 0.194824, 1 clusters with 6 outliers, 0 standard deviation in cluster size
# G0-P1-T1: eps = 0.193652, 3 clusters with 16 outliers, 27 standard deviation in cluster size
# G0-P1-T2: eps = 0.213281, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G0-P1-T2: eps = 0.212402, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G0-P1-T2: eps = 0.211230, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G0-P1-T2: eps = 0.209473, 1 clusters with 4 outliers, 0 standard deviation in cluster size
# G0-P1-T2: eps = 0.207715, 1 clusters with 8 outliers, 0 standard deviation in cluster size
# G0-P1-T2: eps = 0.203906, 3 clusters with 15 outliers, 28 standard deviation in cluster size
# G0-P2-T0: eps = 0.128906, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G0-P2-T0: eps = 0.128906, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G0-P2-T0: eps = 0.125391, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G0-P2-T0: eps = 0.124512, 1 clusters with 4 outliers, 0 standard deviation in cluster size
# G0-P2-T0: eps = 0.123926, 1 clusters with 7 outliers, 0 standard deviation in cluster size
# G0-P2-T0: eps = 0.120410, 1 clusters with 16 outliers, 0 standard deviation in cluster size
# G0-P2-T1: eps = 0.157617, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G0-P2-T1: eps = 0.157031, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G0-P2-T1: eps = 0.154980, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G0-P2-T1: eps = 0.151172, 1 clusters with 4 outliers, 0 standard deviation in cluster size
# G0-P2-T1: eps = 0.144727, 1 clusters with 8 outliers, 0 standard deviation in cluster size
# G0-P2-T1: eps = 0.136816, 1 clusters with 16 outliers, 0 standard deviation in cluster size
# G0-P2-T2: eps = 0.130078, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G0-P2-T2: eps = 0.127734, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G0-P2-T2: eps = 0.126855, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G0-P2-T2: eps = 0.125391, 1 clusters with 4 outliers, 0 standard deviation in cluster size
# G0-P2-T2: eps = 0.124512, 1 clusters with 7 outliers, 0 standard deviation in cluster size
# G0-P2-T2: eps = 0.122168, 1 clusters with 15 outliers, 0 standard deviation in cluster size
# G0-P3-T0: eps = 0.212402, 3 clusters with 0 outliers, 19 standard deviation in cluster size
# G0-P3-T0: eps = 0.212402, 3 clusters with 0 outliers, 19 standard deviation in cluster size
# G0-P3-T0: eps = 0.211816, 3 clusters with 2 outliers, 18 standard deviation in cluster size
# G0-P3-T0: eps = 0.211523, 2 clusters with 4 outliers, 8 standard deviation in cluster size
# G0-P3-T0: eps = 0.210352, 2 clusters with 8 outliers, 8 standard deviation in cluster size
# G0-P3-T0: eps = 0.205957, 4 clusters with 16 outliers, 13 standard deviation in cluster size
# G0-P3-T1: eps = 0.216797, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G0-P3-T1: eps = 0.215332, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G0-P3-T1: eps = 0.215039, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G0-P3-T1: eps = 0.207715, 2 clusters with 4 outliers, 18 standard deviation in cluster size
# G0-P3-T1: eps = 0.206250, 2 clusters with 7 outliers, 18 standard deviation in cluster size
# G0-P3-T1: eps = 0.202148, 5 clusters with 15 outliers, 11 standard deviation in cluster size
# G0-P3-T2: eps = 0.215332, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G0-P3-T2: eps = 0.215332, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G0-P3-T2: eps = 0.206250, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G0-P3-T2: eps = 0.204785, 2 clusters with 4 outliers, 1 standard deviation in cluster size
# G0-P3-T2: eps = 0.202441, 2 clusters with 7 outliers, 2 standard deviation in cluster size
# G0-P3-T2: eps = 0.198926, 2 clusters with 15 outliers, 4 standard deviation in cluster size
# G0-P4-T0: eps = 0.217676, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G0-P4-T0: eps = 0.215625, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G0-P4-T0: eps = 0.215625, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G0-P4-T0: eps = 0.214160, 1 clusters with 4 outliers, 0 standard deviation in cluster size
# G0-P4-T0: eps = 0.212695, 2 clusters with 8 outliers, 34 standard deviation in cluster size
# G0-P4-T0: eps = 0.211523, 2 clusters with 16 outliers, 30 standard deviation in cluster size
# G0-P4-T1: eps = 0.225293, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G0-P4-T1: eps = 0.222656, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G0-P4-T1: eps = 0.220020, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G0-P4-T1: eps = 0.219434, 1 clusters with 3 outliers, 0 standard deviation in cluster size
# G0-P4-T1: eps = 0.216211, 1 clusters with 8 outliers, 0 standard deviation in cluster size
# G0-P4-T1: eps = 0.213281, 1 clusters with 16 outliers, 0 standard deviation in cluster size
# G0-P4-T2: eps = 0.204492, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G0-P4-T2: eps = 0.203906, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G0-P4-T2: eps = 0.203027, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G0-P4-T2: eps = 0.200977, 1 clusters with 4 outliers, 0 standard deviation in cluster size
# G0-P4-T2: eps = 0.199219, 1 clusters with 8 outliers, 0 standard deviation in cluster size
# G0-P4-T2: eps = 0.197754, 1 clusters with 14 outliers, 0 standard deviation in cluster size
# G0-P5-T0: eps = 0.224414, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G0-P5-T0: eps = 0.223535, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G0-P5-T0: eps = 0.221777, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G0-P5-T0: eps = 0.219434, 1 clusters with 4 outliers, 0 standard deviation in cluster size
# G0-P5-T0: eps = 0.215918, 1 clusters with 8 outliers, 0 standard deviation in cluster size
# G0-P5-T0: eps = 0.208301, 3 clusters with 15 outliers, 28 standard deviation in cluster size
# G0-P5-T1: eps = 0.224121, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G0-P5-T1: eps = 0.221191, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G0-P5-T1: eps = 0.221191, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G0-P5-T1: eps = 0.212402, 1 clusters with 4 outliers, 0 standard deviation in cluster size
# G0-P5-T1: eps = 0.208301, 1 clusters with 8 outliers, 0 standard deviation in cluster size
# G0-P5-T1: eps = 0.203027, 1 clusters with 14 outliers, 0 standard deviation in cluster size
# G0-P5-T2: eps = 0.290918, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G0-P5-T2: eps = 0.289453, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G0-P5-T2: eps = 0.288281, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G0-P5-T2: eps = 0.283594, 1 clusters with 4 outliers, 0 standard deviation in cluster size
# G0-P5-T2: eps = 0.209766, 1 clusters with 8 outliers, 0 standard deviation in cluster size
# G0-P5-T2: eps = 0.205371, 1 clusters with 15 outliers, 0 standard deviation in cluster size
# G0-P6-T0: eps = 0.195410, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G0-P6-T0: eps = 0.189844, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G0-P6-T0: eps = 0.186621, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G0-P6-T0: eps = 0.182812, 1 clusters with 4 outliers, 0 standard deviation in cluster size
# G0-P6-T0: eps = 0.166113, 2 clusters with 8 outliers, 34 standard deviation in cluster size
# G0-P6-T0: eps = 0.161719, 4 clusters with 16 outliers, 24 standard deviation in cluster size
# G0-P6-T1: eps = 0.200391, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G0-P6-T1: eps = 0.198633, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G0-P6-T1: eps = 0.192773, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G0-P6-T1: eps = 0.186328, 1 clusters with 4 outliers, 0 standard deviation in cluster size
# G0-P6-T1: eps = 0.161133, 1 clusters with 8 outliers, 0 standard deviation in cluster size
# G0-P6-T1: eps = 0.155566, 1 clusters with 16 outliers, 0 standard deviation in cluster size
# G0-P6-T2: eps = 0.176953, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G0-P6-T2: eps = 0.176074, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G0-P6-T2: eps = 0.175488, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G0-P6-T2: eps = 0.170801, 1 clusters with 4 outliers, 0 standard deviation in cluster size
# G0-P6-T2: eps = 0.167285, 1 clusters with 8 outliers, 0 standard deviation in cluster size
# G0-P6-T2: eps = 0.162305, 1 clusters with 16 outliers, 0 standard deviation in cluster size
# G0-P7-T0: eps = 0.155566, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G0-P7-T0: eps = 0.150000, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G0-P7-T0: eps = 0.148828, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G0-P7-T0: eps = 0.145313, 1 clusters with 4 outliers, 0 standard deviation in cluster size
# G0-P7-T0: eps = 0.139453, 1 clusters with 8 outliers, 0 standard deviation in cluster size
# G0-P7-T0: eps = 0.134766, 1 clusters with 16 outliers, 0 standard deviation in cluster size
# G0-P7-T1: eps = 0.161426, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G0-P7-T1: eps = 0.157910, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G0-P7-T1: eps = 0.157617, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G0-P7-T1: eps = 0.152637, 1 clusters with 3 outliers, 0 standard deviation in cluster size
# G0-P7-T1: eps = 0.149414, 1 clusters with 8 outliers, 0 standard deviation in cluster size
# G0-P7-T1: eps = 0.145020, 1 clusters with 16 outliers, 0 standard deviation in cluster size
# G0-P7-T2: eps = 0.146777, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G0-P7-T2: eps = 0.143555, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G0-P7-T2: eps = 0.142676, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G0-P7-T2: eps = 0.141797, 1 clusters with 3 outliers, 0 standard deviation in cluster size
# G0-P7-T2: eps = 0.136523, 1 clusters with 8 outliers, 0 standard deviation in cluster size
# G0-P7-T2: eps = 0.128027, 1 clusters with 16 outliers, 0 standard deviation in cluster size
# G1-P0-T0: eps = 0.218262, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G1-P0-T0: eps = 0.213867, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G1-P0-T0: eps = 0.213574, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G1-P0-T0: eps = 0.211230, 1 clusters with 4 outliers, 0 standard deviation in cluster size
# G1-P0-T0: eps = 0.208301, 1 clusters with 8 outliers, 0 standard deviation in cluster size
# G1-P0-T0: eps = 0.205371, 2 clusters with 16 outliers, 30 standard deviation in cluster size
# G1-P0-T1: eps = 0.220020, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G1-P0-T1: eps = 0.219434, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G1-P0-T1: eps = 0.212695, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G1-P0-T1: eps = 0.209473, 1 clusters with 4 outliers, 0 standard deviation in cluster size
# G1-P0-T1: eps = 0.205664, 1 clusters with 8 outliers, 0 standard deviation in cluster size
# G1-P0-T1: eps = 0.199805, 1 clusters with 15 outliers, 0 standard deviation in cluster size
# G1-P0-T2: eps = 0.226172, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G1-P0-T2: eps = 0.220312, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G1-P0-T2: eps = 0.218262, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G1-P0-T2: eps = 0.213281, 1 clusters with 4 outliers, 0 standard deviation in cluster size
# G1-P0-T2: eps = 0.212402, 1 clusters with 7 outliers, 0 standard deviation in cluster size
# G1-P0-T2: eps = 0.210645, 1 clusters with 16 outliers, 0 standard deviation in cluster size
# G1-P1-T0: eps = 0.191895, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G1-P1-T0: eps = 0.191602, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G1-P1-T0: eps = 0.189258, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G1-P1-T0: eps = 0.186328, 1 clusters with 3 outliers, 0 standard deviation in cluster size
# G1-P1-T0: eps = 0.184863, 2 clusters with 8 outliers, 34 standard deviation in cluster size
# G1-P1-T0: eps = 0.181348, 1 clusters with 15 outliers, 0 standard deviation in cluster size
# G1-P1-T1: eps = 0.207422, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G1-P1-T1: eps = 0.201270, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G1-P1-T1: eps = 0.199805, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G1-P1-T1: eps = 0.198340, 1 clusters with 4 outliers, 0 standard deviation in cluster size
# G1-P1-T1: eps = 0.194824, 1 clusters with 8 outliers, 0 standard deviation in cluster size
# G1-P1-T1: eps = 0.191309, 1 clusters with 15 outliers, 0 standard deviation in cluster size
# G1-P1-T2: eps = 0.215918, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G1-P1-T2: eps = 0.215625, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G1-P1-T2: eps = 0.213867, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G1-P1-T2: eps = 0.205664, 1 clusters with 4 outliers, 0 standard deviation in cluster size
# G1-P1-T2: eps = 0.199512, 1 clusters with 8 outliers, 0 standard deviation in cluster size
# G1-P1-T2: eps = 0.194531, 4 clusters with 16 outliers, 23 standard deviation in cluster size
# G1-P2-T0: eps = 0.147656, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G1-P2-T0: eps = 0.146484, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G1-P2-T0: eps = 0.141211, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G1-P2-T0: eps = 0.140332, 1 clusters with 4 outliers, 0 standard deviation in cluster size
# G1-P2-T0: eps = 0.137695, 1 clusters with 8 outliers, 0 standard deviation in cluster size
# G1-P2-T0: eps = 0.131836, 1 clusters with 15 outliers, 0 standard deviation in cluster size
# G1-P2-T1: eps = 0.140332, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G1-P2-T1: eps = 0.139746, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G1-P2-T1: eps = 0.137402, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G1-P2-T1: eps = 0.133887, 2 clusters with 4 outliers, 36 standard deviation in cluster size
# G1-P2-T1: eps = 0.132715, 2 clusters with 7 outliers, 34 standard deviation in cluster size
# G1-P2-T1: eps = 0.129785, 1 clusters with 16 outliers, 0 standard deviation in cluster size
# G1-P2-T2: eps = 0.169922, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G1-P2-T2: eps = 0.165234, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G1-P2-T2: eps = 0.156738, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G1-P2-T2: eps = 0.153809, 1 clusters with 3 outliers, 0 standard deviation in cluster size
# G1-P2-T2: eps = 0.147949, 2 clusters with 8 outliers, 34 standard deviation in cluster size
# G1-P2-T2: eps = 0.139746, 2 clusters with 16 outliers, 30 standard deviation in cluster size
# G1-P3-T0: eps = 0.216504, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G1-P3-T0: eps = 0.209766, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G1-P3-T0: eps = 0.209473, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G1-P3-T0: eps = 0.205957, 2 clusters with 4 outliers, 36 standard deviation in cluster size
# G1-P3-T0: eps = 0.200391, 1 clusters with 8 outliers, 0 standard deviation in cluster size
# G1-P3-T0: eps = 0.192773, 1 clusters with 16 outliers, 0 standard deviation in cluster size
# G1-P3-T1: eps = 0.210645, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G1-P3-T1: eps = 0.206543, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G1-P3-T1: eps = 0.206250, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G1-P3-T1: eps = 0.205664, 1 clusters with 3 outliers, 0 standard deviation in cluster size
# G1-P3-T1: eps = 0.202441, 1 clusters with 8 outliers, 0 standard deviation in cluster size
# G1-P3-T1: eps = 0.198047, 1 clusters with 15 outliers, 0 standard deviation in cluster size
# G1-P3-T2: eps = 0.200391, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G1-P3-T2: eps = 0.196289, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G1-P3-T2: eps = 0.195410, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G1-P3-T2: eps = 0.194238, 1 clusters with 4 outliers, 0 standard deviation in cluster size
# G1-P3-T2: eps = 0.191309, 1 clusters with 8 outliers, 0 standard deviation in cluster size
# G1-P3-T2: eps = 0.188086, 1 clusters with 16 outliers, 0 standard deviation in cluster size
# G1-P4-T0: eps = 0.227344, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G1-P4-T0: eps = 0.227051, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G1-P4-T0: eps = 0.224707, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G1-P4-T0: eps = 0.222363, 1 clusters with 4 outliers, 0 standard deviation in cluster size
# G1-P4-T0: eps = 0.220020, 1 clusters with 8 outliers, 0 standard deviation in cluster size
# G1-P4-T0: eps = 0.211816, 1 clusters with 16 outliers, 0 standard deviation in cluster size
# G1-P4-T1: eps = 0.215918, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G1-P4-T1: eps = 0.209473, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G1-P4-T1: eps = 0.208008, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G1-P4-T1: eps = 0.205664, 1 clusters with 4 outliers, 0 standard deviation in cluster size
# G1-P4-T1: eps = 0.203320, 1 clusters with 8 outliers, 0 standard deviation in cluster size
# G1-P4-T1: eps = 0.198926, 1 clusters with 16 outliers, 0 standard deviation in cluster size
# G1-P4-T2: eps = 0.212109, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G1-P4-T2: eps = 0.211816, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G1-P4-T2: eps = 0.210938, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G1-P4-T2: eps = 0.208887, 1 clusters with 4 outliers, 0 standard deviation in cluster size
# G1-P4-T2: eps = 0.207129, 1 clusters with 8 outliers, 0 standard deviation in cluster size
# G1-P4-T2: eps = 0.205078, 1 clusters with 14 outliers, 0 standard deviation in cluster size
# G1-P5-T0: eps = 0.248437, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G1-P5-T0: eps = 0.248145, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G1-P5-T0: eps = 0.245508, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G1-P5-T0: eps = 0.241699, 1 clusters with 4 outliers, 0 standard deviation in cluster size
# G1-P5-T0: eps = 0.222656, 1 clusters with 8 outliers, 0 standard deviation in cluster size
# G1-P5-T0: eps = 0.206543, 1 clusters with 16 outliers, 0 standard deviation in cluster size
# G1-P5-T1: eps = 0.219434, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G1-P5-T1: eps = 0.215332, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G1-P5-T1: eps = 0.213574, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G1-P5-T1: eps = 0.210645, 3 clusters with 4 outliers, 33 standard deviation in cluster size
# G1-P5-T1: eps = 0.203613, 2 clusters with 8 outliers, 34 standard deviation in cluster size
# G1-P5-T1: eps = 0.200684, 3 clusters with 12 outliers, 29 standard deviation in cluster size
# G1-P5-T2: eps = 0.229102, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G1-P5-T2: eps = 0.218555, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G1-P5-T2: eps = 0.214746, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G1-P5-T2: eps = 0.213574, 1 clusters with 4 outliers, 0 standard deviation in cluster size
# G1-P5-T2: eps = 0.208008, 1 clusters with 8 outliers, 0 standard deviation in cluster size
# G1-P5-T2: eps = 0.203027, 1 clusters with 16 outliers, 0 standard deviation in cluster size
# G1-P6-T0: eps = 0.180762, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G1-P6-T0: eps = 0.178711, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G1-P6-T0: eps = 0.169336, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G1-P6-T0: eps = 0.167871, 1 clusters with 4 outliers, 0 standard deviation in cluster size
# G1-P6-T0: eps = 0.164648, 1 clusters with 8 outliers, 0 standard deviation in cluster size
# G1-P6-T0: eps = 0.160547, 1 clusters with 16 outliers, 0 standard deviation in cluster size
# G1-P6-T1: eps = 0.184277, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G1-P6-T1: eps = 0.182227, 1 clusters with 1 outliers, 0 standard deviation in cluster size
# G1-P6-T1: eps = 0.171973, 1 clusters with 2 outliers, 0 standard deviation in cluster size
# G1-P6-T1: eps = 0.168750, 1 clusters with 4 outliers, 0 standard deviation in cluster size
# G1-P6-T1: eps = 0.158496, 1 clusters with 8 outliers, 0 standard deviation in cluster size
# G1-P6-T1: eps = 0.152930, 2 clusters with 15 outliers, 30 standard deviation in cluster size
# G1-P6-T2: eps = 0.219727, 1 clusters with 0 outliers, 0 standard deviation in cluster size
# G1-P6-T2:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-6a72baf16e7f> in <module>
#      16                 numIter = 12
#      17                 for x in range(numIter):
# ---> 18                     db = DBSCAN(eps=currEps,min_samples=minSamples,metric='hamming',n_jobs=-1).fit(hv[(gestLabel==g) & (posLabel==p) & (trialLabel==t)])
#      19                     numOutliers = len(db.labels_[db.labels_<0])
#      20                     if numOutliers <= o:
#
# ~/opt/anaconda3/envs/hdcpar/lib/python3.7/site-packages/sklearn/cluster/_dbscan.py in fit(self, X, y, sample_weight)
#     333         # This has worst case O(n^2) memory complexity
#     334         neighborhoods = neighbors_model.radius_neighbors(X,
# --> 335                                                          return_distance=False)
#     336
#     337         if sample_weight is None:
#
# ~/opt/anaconda3/envs/hdcpar/lib/python3.7/site-packages/sklearn/neighbors/_base.py in radius_neighbors(self, X, radius, return_distance, sort_results)
#     973                               sort_results=sort_results)
#     974
# --> 975                 for s in gen_even_slices(X.shape[0], n_jobs)
#     976             )
#     977             if return_distance:
#
# ~/opt/anaconda3/envs/hdcpar/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1050                 self._backend.stop_call()
#    1051             if not self._managed_backend:
# -> 1052                 self._terminate_backend()
#    1053             self._jobs = list()
#    1054             self._pickle_cache = None
#
# ~/opt/anaconda3/envs/hdcpar/lib/python3.7/site-packages/joblib/parallel.py in _terminate_backend(self)
#     743     def _terminate_backend(self):
#     744         if self._backend is not None:
# --> 745             self._backend.terminate()
#     746
#     747     def _dispatch(self, batch):
#
# ~/opt/anaconda3/envs/hdcpar/lib/python3.7/site-packages/joblib/_parallel_backends.py in terminate(self)
#     239         if self._pool is not None:
#     240             self._pool.close()
# --> 241             self._pool.terminate()  # terminate does a join()
#     242             self._pool = None
#     243
#
# ~/opt/anaconda3/envs/hdcpar/lib/python3.7/multiprocessing/pool.py in terminate(self)
#     546         self._state = TERMINATE
#     547         self._worker_handler._state = TERMINATE
# --> 548         self._terminate()
#     549
#     550     def join(self):
#
# ~/opt/anaconda3/envs/hdcpar/lib/python3.7/multiprocessing/util.py in __call__(self, wr, _finalizer_registry, sub_debug, getpid)
#     199                 sub_debug('finalizer calling %s with args %s and kwargs %s',
#     200                           self._callback, self._args, self._kwargs)
# --> 201                 res = self._callback(*self._args, **self._kwargs)
#     202             self._weakref = self._callback = self._args = \
#     203                             self._kwargs = self._key = None
#
# ~/opt/anaconda3/envs/hdcpar/lib/python3.7/multiprocessing/pool.py in _terminate_pool(cls, taskqueue, inqueue, outqueue, pool, worker_handler, task_handler, result_handler, cache)
#     592         util.debug('joining worker handler')
#     593         if threading.current_thread() is not worker_handler:
# --> 594             worker_handler.join()
#     595
#     596         # Terminate workers which haven't already finished.
#
# ~/opt/anaconda3/envs/hdcpar/lib/python3.7/threading.py in join(self, timeout)
#    1042
#    1043         if timeout is None:
# -> 1044             self._wait_for_tstate_lock()
#    1045         else:
#    1046             # the behavior of a negative timeout isn't documented, but
#
# ~/opt/anaconda3/envs/hdcpar/lib/python3.7/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1058         if lock is None:  # already determined that the C code is done
#    1059             assert self._is_stopped
# -> 1060         elif lock.acquire(block, timeout):
#    1061             lock.release()
#    1062             self._stop()
#
# KeyboardInterrupt:

# %%
for g in range(numGestures):
    for p in range(numPositions):
        for t in range(numTrials):
# Out:
# [0, 1, 2, 3]
